# %%
from glob import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('clean_data\clean_data_v2.csv')
df
# Out:
#                                                   Crime ID    Month
# 0        c9e13644419c09d866b0677c611c270a7ec07469b07b22...  2020-02  \
# 1        b56fb9a76ae74d64bcf2a977260f288ecc0368c287c003...  2020-02
# 2        a645e84c245557bc94c24543bc3fbb001da8bf58c0aa8a...  2020-02
# 3        adb977ce325d741b951aee2b769015322b74f857ce81b7...  2020-02
# 4        b213f886ce58f48c9ca2c39745ab1b8a1825e3239a6ae6...  2020-02
# ...                                                    ...      ...
# 2130544  e5ad1fe3d37c380049cd9b41335af39a3b90efa87cca84...  2023-01
# 2130545  474af4ae9e4f8813c2e5d983d663bb4e1347d1df474a7d...  2023-01
# 2130546  7b01c0f45837c1cb1c75d03f422bc6e34e05148cf6d973...  2023-01
# 2130547  2aa6988775439e9c1b52f17d13d6e434e0f3c91b70fed0...  2023-01
# 2130548  15fab599887a2d8b9312d595c60dc1f74fea52277f99e9...  2023-01
#
#                             Reported by                    Falls within
# 0        Avon and Somerset Constabulary  Avon and Somerset Constabulary  \
# 1        Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 2        Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 3        Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 4        Avon and Somerset Constabulary  Avon and Somerset Constabulary
# ...                                 ...                             ...
# 2130544                Wiltshire Police                Wiltshire Police
# 2130545                Wiltshire Police                Wiltshire Police
# 2130546                Wiltshire Police                Wiltshire Police
# 2130547                Wiltshire Police                Wiltshire Police
# 2130548                Wiltshire Police                Wiltshire Police
#
#          Longitude   Latitude                  Location  LSOA code
# 0        -2.350371  51.391561    On or near Supermarket  E01014468  \
# 1        -2.360522  51.381127  On or near Shopping Area  E01014370
# 2        -2.359175  51.383451   On or near Parking Area  E01014370
# 3        -2.359175  51.383451   On or near Parking Area  E01014370
# 4        -2.359175  51.383451   On or near Parking Area  E01014370
# ...            ...        ...                       ...        ...
# 2130544  -1.759022  50.994660               On or near   E01031995
# 2130545  -1.759022  50.994660               On or near   E01031995
# 2130546  -1.759022  50.994660               On or near   E01031995
# 2130547  -1.750954  50.992992    On or near The Borough  E01031995
# 2130548  -1.748516  50.993355     On or near Green Lane  E01031995
#
#                                  LSOA name     Crime type
# 0        Bath and North East Somerset 006D        Robbery  \
# 1        Bath and North East Somerset 007A   Public order
# 2        Bath and North East Somerset 007A        Robbery
# 3        Bath and North East Somerset 007A    Shoplifting
# 4        Bath and North East Somerset 007A    Shoplifting
# ...                                    ...            ...
# 2130544                     Wiltshire 062E    Other theft
# 2130545                     Wiltshire 062E    Other theft
# 2130546                     Wiltshire 062E    Other theft
# 2130547                     Wiltshire 062E    Shoplifting
# 2130548                     Wiltshire 062E  Vehicle crime
#
#                                               Outcome type
# 0            Investigation complete; no suspect identified
# 1        Further investigation is not in the public int...
# 2                                          Suspect charged
# 3                                          Suspect charged
# 4                                          Suspect charged
# ...                                                    ...
# 2130544      Investigation complete; no suspect identified
# 2130545      Investigation complete; no suspect identified
# 2130546      Investigation complete; no suspect identified
# 2130547      Investigation complete; no suspect identified
# 2130548      Investigation complete; no suspect identified
#
# [2130549 rows x 11 columns]

# %%
df.drop(['Crime ID', 'LSOA name'], axis=1, inplace=True, errors='ignore')

# %%
df
# Out:
#            Month                     Reported by
# 0        2020-02  Avon and Somerset Constabulary  \
# 1        2020-02  Avon and Somerset Constabulary
# 2        2020-02  Avon and Somerset Constabulary
# 3        2020-02  Avon and Somerset Constabulary
# 4        2020-02  Avon and Somerset Constabulary
# ...          ...                             ...
# 2130544  2023-01                Wiltshire Police
# 2130545  2023-01                Wiltshire Police
# 2130546  2023-01                Wiltshire Police
# 2130547  2023-01                Wiltshire Police
# 2130548  2023-01                Wiltshire Police
#
#                            Falls within  Longitude   Latitude
# 0        Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1        Avon and Somerset Constabulary  -2.360522  51.381127
# 2        Avon and Somerset Constabulary  -2.359175  51.383451
# 3        Avon and Somerset Constabulary  -2.359175  51.383451
# 4        Avon and Somerset Constabulary  -2.359175  51.383451
# ...                                 ...        ...        ...
# 2130544                Wiltshire Police  -1.759022  50.994660
# 2130545                Wiltshire Police  -1.759022  50.994660
# 2130546                Wiltshire Police  -1.759022  50.994660
# 2130547                Wiltshire Police  -1.750954  50.992992
# 2130548                Wiltshire Police  -1.748516  50.993355
#
#                          Location  LSOA code     Crime type
# 0          On or near Supermarket  E01014468        Robbery  \
# 1        On or near Shopping Area  E01014370   Public order
# 2         On or near Parking Area  E01014370        Robbery
# 3         On or near Parking Area  E01014370    Shoplifting
# 4         On or near Parking Area  E01014370    Shoplifting
# ...                           ...        ...            ...
# 2130544               On or near   E01031995    Other theft
# 2130545               On or near   E01031995    Other theft
# 2130546               On or near   E01031995    Other theft
# 2130547    On or near The Borough  E01031995    Shoplifting
# 2130548     On or near Green Lane  E01031995  Vehicle crime
#
#                                               Outcome type
# 0            Investigation complete; no suspect identified
# 1        Further investigation is not in the public int...
# 2                                          Suspect charged
# 3                                          Suspect charged
# 4                                          Suspect charged
# ...                                                    ...
# 2130544      Investigation complete; no suspect identified
# 2130545      Investigation complete; no suspect identified
# 2130546      Investigation complete; no suspect identified
# 2130547      Investigation complete; no suspect identified
# 2130548      Investigation complete; no suspect identified
#
# [2130549 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2130549 entries, 0 to 2130548
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Month         object
#  1   Reported by   object
#  2   Falls within  object
#  3   Longitude     float64
#  4   Latitude      float64
#  5   Location      object
#  6   LSOA code     object
#  7   Crime type    object
#  8   Outcome type  object
# dtypes: float64(2), object(7)
# memory usage: 146.3+ MB

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df
# Out:
#              Month                     Reported by
# 0       2020-02-01  Avon and Somerset Constabulary  \
# 1       2020-02-01  Avon and Somerset Constabulary
# 2       2020-02-01  Avon and Somerset Constabulary
# 3       2020-02-01  Avon and Somerset Constabulary
# 4       2020-02-01  Avon and Somerset Constabulary
# ...            ...                             ...
# 2130544 2023-01-01                Wiltshire Police
# 2130545 2023-01-01                Wiltshire Police
# 2130546 2023-01-01                Wiltshire Police
# 2130547 2023-01-01                Wiltshire Police
# 2130548 2023-01-01                Wiltshire Police
#
#                            Falls within  Longitude   Latitude
# 0        Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1        Avon and Somerset Constabulary  -2.360522  51.381127
# 2        Avon and Somerset Constabulary  -2.359175  51.383451
# 3        Avon and Somerset Constabulary  -2.359175  51.383451
# 4        Avon and Somerset Constabulary  -2.359175  51.383451
# ...                                 ...        ...        ...
# 2130544                Wiltshire Police  -1.759022  50.994660
# 2130545                Wiltshire Police  -1.759022  50.994660
# 2130546                Wiltshire Police  -1.759022  50.994660
# 2130547                Wiltshire Police  -1.750954  50.992992
# 2130548                Wiltshire Police  -1.748516  50.993355
#
#                          Location  LSOA code     Crime type
# 0          On or near Supermarket  E01014468        Robbery  \
# 1        On or near Shopping Area  E01014370   Public order
# 2         On or near Parking Area  E01014370        Robbery
# 3         On or near Parking Area  E01014370    Shoplifting
# 4         On or near Parking Area  E01014370    Shoplifting
# ...                           ...        ...            ...
# 2130544               On or near   E01031995    Other theft
# 2130545               On or near   E01031995    Other theft
# 2130546               On or near   E01031995    Other theft
# 2130547    On or near The Borough  E01031995    Shoplifting
# 2130548     On or near Green Lane  E01031995  Vehicle crime
#
#                                               Outcome type
# 0            Investigation complete; no suspect identified
# 1        Further investigation is not in the public int...
# 2                                          Suspect charged
# 3                                          Suspect charged
# 4                                          Suspect charged
# ...                                                    ...
# 2130544      Investigation complete; no suspect identified
# 2130545      Investigation complete; no suspect identified
# 2130546      Investigation complete; no suspect identified
# 2130547      Investigation complete; no suspect identified
# 2130548      Investigation complete; no suspect identified
#
# [2130549 rows x 9 columns]

# %%
df[df['Reported by'] != df['Falls within']]
# Out:
# Empty DataFrame
# Columns: [Month, Reported by, Falls within, Longitude, Latitude, Location, LSOA code, Crime type, Outcome type]
# Index: []

# %%
df.drop(['Reported by', 'Location'], axis=1, inplace=True, errors='ignore')

# %%
df
# Out:
#              Month                    Falls within  Longitude   Latitude
# 0       2020-02-01  Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1       2020-02-01  Avon and Somerset Constabulary  -2.360522  51.381127
# 2       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 3       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 4       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# ...            ...                             ...        ...        ...
# 2130544 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130545 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130546 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130547 2023-01-01                Wiltshire Police  -1.750954  50.992992
# 2130548 2023-01-01                Wiltshire Police  -1.748516  50.993355
#
#          LSOA code     Crime type
# 0        E01014468        Robbery  \
# 1        E01014370   Public order
# 2        E01014370        Robbery
# 3        E01014370    Shoplifting
# 4        E01014370    Shoplifting
# ...            ...            ...
# 2130544  E01031995    Other theft
# 2130545  E01031995    Other theft
# 2130546  E01031995    Other theft
# 2130547  E01031995    Shoplifting
# 2130548  E01031995  Vehicle crime
#
#                                               Outcome type
# 0            Investigation complete; no suspect identified
# 1        Further investigation is not in the public int...
# 2                                          Suspect charged
# 3                                          Suspect charged
# 4                                          Suspect charged
# ...                                                    ...
# 2130544      Investigation complete; no suspect identified
# 2130545      Investigation complete; no suspect identified
# 2130546      Investigation complete; no suspect identified
# 2130547      Investigation complete; no suspect identified
# 2130548      Investigation complete; no suspect identified
#
# [2130549 rows x 7 columns]

# %%
df.loc[:, 'Outcome type'] = df.loc[:, 'Outcome type'].apply(lambda x: 'prosecuted' if 'charged' in x else 'not-prosecuted')

# %%
df
# Out:
#              Month                    Falls within  Longitude   Latitude
# 0       2020-02-01  Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1       2020-02-01  Avon and Somerset Constabulary  -2.360522  51.381127
# 2       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 3       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 4       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# ...            ...                             ...        ...        ...
# 2130544 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130545 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130546 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130547 2023-01-01                Wiltshire Police  -1.750954  50.992992
# 2130548 2023-01-01                Wiltshire Police  -1.748516  50.993355
#
#          LSOA code     Crime type    Outcome type
# 0        E01014468        Robbery  not-prosecuted
# 1        E01014370   Public order  not-prosecuted
# 2        E01014370        Robbery      prosecuted
# 3        E01014370    Shoplifting      prosecuted
# 4        E01014370    Shoplifting      prosecuted
# ...            ...            ...             ...
# 2130544  E01031995    Other theft  not-prosecuted
# 2130545  E01031995    Other theft  not-prosecuted
# 2130546  E01031995    Other theft  not-prosecuted
# 2130547  E01031995    Shoplifting  not-prosecuted
# 2130548  E01031995  Vehicle crime  not-prosecuted
#
# [2130549 rows x 7 columns]

# %%
len(df['LSOA code'].unique())
# Out:
# 33066

# %%
df['Outcome type'].value_counts()/len(df) * 100
# Out:
# Outcome type
# not-prosecuted    94.843301
# prosecuted         5.156699
# Name: count, dtype: float64

# %%
df['Crime type'].unique()
# Out:
# array(['Robbery', 'Public order', 'Shoplifting',
#        'Violence and sexual offences', 'Criminal damage and arson',
#        'Other theft', 'Other crime', 'Possession of weapons',
#        'Vehicle crime', 'Drugs', 'Burglary', 'Bicycle theft',
#        'Theft from the person'], dtype=object)

# %%
df[df['Crime type'] == 'Possession of weapons']['Outcome type'].value_counts()/len(df[df['Crime type'] == 'Possession of weapons']) * 100
# Out:
# Outcome type
# not-prosecuted    61.948139
# prosecuted        38.051861
# Name: count, dtype: float64

# %%
outcome_map = {'not-prosecuted':0, 'prosecuted':1}
outcome_map
# Out:
# {'not-prosecuted': 0, 'prosecuted': 1}

# %%
df['Outcome type'] = df['Outcome type'].map(outcome_map)

# %%
df
# Out:
#              Month                    Falls within  Longitude   Latitude
# 0       2020-02-01  Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1       2020-02-01  Avon and Somerset Constabulary  -2.360522  51.381127
# 2       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 3       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 4       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# ...            ...                             ...        ...        ...
# 2130544 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130545 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130546 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130547 2023-01-01                Wiltshire Police  -1.750954  50.992992
# 2130548 2023-01-01                Wiltshire Police  -1.748516  50.993355
#
#          LSOA code     Crime type  Outcome type
# 0        E01014468        Robbery             0
# 1        E01014370   Public order             0
# 2        E01014370        Robbery             1
# 3        E01014370    Shoplifting             1
# 4        E01014370    Shoplifting             1
# ...            ...            ...           ...
# 2130544  E01031995    Other theft             0
# 2130545  E01031995    Other theft             0
# 2130546  E01031995    Other theft             0
# 2130547  E01031995    Shoplifting             0
# 2130548  E01031995  Vehicle crime             0
#
# [2130549 rows x 7 columns]

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Importing libraries

# %%
import os

from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import f1_score, confusion_matrix, 

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
def year_month(df, col):
    df['year'] = df.loc[:, col].dt.year
    df['month'] = df.loc[:, col].dt.month
    
    return df

# %%
year_month(df=df, col='Month')
# Out:
#              Month                    Falls within  Longitude   Latitude
# 0       2020-02-01  Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1       2020-02-01  Avon and Somerset Constabulary  -2.360522  51.381127
# 2       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 3       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# 4       2020-02-01  Avon and Somerset Constabulary  -2.359175  51.383451
# ...            ...                             ...        ...        ...
# 2130544 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130545 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130546 2023-01-01                Wiltshire Police  -1.759022  50.994660
# 2130547 2023-01-01                Wiltshire Police  -1.750954  50.992992
# 2130548 2023-01-01                Wiltshire Police  -1.748516  50.993355
#
#          LSOA code     Crime type  Outcome type  year  month
# 0        E01014468        Robbery             0  2020      2
# 1        E01014370   Public order             0  2020      2
# 2        E01014370        Robbery             1  2020      2
# 3        E01014370    Shoplifting             1  2020      2
# 4        E01014370    Shoplifting             1  2020      2
# ...            ...            ...           ...   ...    ...
# 2130544  E01031995    Other theft             0  2023      1
# 2130545  E01031995    Other theft             0  2023      1
# 2130546  E01031995    Other theft             0  2023      1
# 2130547  E01031995    Shoplifting             0  2023      1
# 2130548  E01031995  Vehicle crime             0  2023      1
#
# [2130549 rows x 9 columns]

# %%
df.drop(['Month'], errors='ignore', inplace=True, axis=1)

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=4)

# %%
mean_encoded = df_train.groupby(['LSOA code'])['Outcome type'].mean().to_dict()

# %%
df_train['LSOA code'] = df_train['LSOA code'].map(mean_encoded)
df_train
# Out:
#                          Falls within  Longitude   Latitude  LSOA code
# 1273950  Gloucestershire Constabulary  -2.201991  51.839291   0.050000  \
# 164444           Thames Valley Police  -1.201400  51.948703   0.008955
# 305607    Metropolitan Police Service   0.057743  51.514884   0.061856
# 1876867            South Wales Police  -3.754138  51.592297   0.076923
# 1768149         West Yorkshire Police  -1.497631  53.697094   0.041667
# ...                               ...        ...        ...        ...
# 653672            Lincolnshire Police  -0.604097  53.215015   0.040816
# 120705              Humberside Police  -0.644283  53.591509   0.112132
# 1534391          Staffordshire Police  -2.208193  53.000311   0.072165
# 991406         South Yorkshire Police  -1.476687  53.469365   0.043478
# 1000570          Suffolk Constabulary   1.602002  52.450554   0.000000
#
#                            Crime type  Outcome type  year  month
# 1273950                  Public order             0  2022      9
# 164444                  Vehicle crime             0  2020      7
# 305607                    Other theft             0  2020     12
# 1876867     Criminal damage and arson             0  2022     12
# 1768149  Violence and sexual offences             0  2022     11
# ...                               ...           ...   ...    ...
# 653672      Criminal damage and arson             0  2021     12
# 120705                  Vehicle crime             0  2020      6
# 1534391  Violence and sexual offences             0  2022     10
# 991406      Criminal damage and arson             0  2022      7
# 1000570                 Vehicle crime             0  2022      7
#
# [1704439 rows x 8 columns]

# %%
df_test['LSOA code'] = df_test['LSOA code'].map(mean_encoded)

# %%
df_test
# Out:
#                         Falls within  Longitude   Latitude  LSOA code
# 45643    Metropolitan Police Service   0.020246  51.488621   0.014493  \
# 291136         West Yorkshire Police  -1.576313  53.798164   0.041534
# 2128754        West Yorkshire Police  -1.347497  53.670341   0.000000
# 2002382        Leicestershire Police  -1.072679  52.691319   0.071429
# 571644          West Midlands Police  -2.036162  52.568228   0.035857
# ...                              ...        ...        ...        ...
# 357424          Thames Valley Police  -0.709510  51.584146   0.000000
# 1899596         Thames Valley Police  -0.803395  52.008423   0.016667
# 670575          West Midlands Police  -1.894919  52.478199   0.080961
# 2089611         Thames Valley Police  -0.728785  51.637678   0.000000
# 656999   Metropolitan Police Service  -0.481613  51.547411   0.094737
#
#                            Crime type  Outcome type  year  month
# 45643                   Vehicle crime             0  2020      3
# 291136                    Other theft             0  2020     11
# 2128754  Violence and sexual offences             0  2023      1
# 2002382     Criminal damage and arson             0  2023      1
# 571644                   Public order             0  2021      9
# ...                               ...           ...   ...    ...
# 357424   Violence and sexual offences             0  2021      2
# 1899596                   Other theft             0  2022     12
# 670575                    Shoplifting             0  2021     12
# 2089611                 Vehicle crime             0  2023      1
# 656999          Theft from the person             0  2021     12
#
# [426110 rows x 8 columns]

# %%
df_test.isna().sum()/(len(df_test))*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_test.isna().sum()/(len(df_test))*100
#
# NameError: name 'df_test' is not defined

# %%
df_test['LSOA code'].fillna(df_test["LSOA code"].mode()[0], inplace=True)

# %%
df_test.isna().sum()/(len(df_test))*100
# Out:
# Falls within    0.0
# Longitude       0.0
# Latitude        0.0
# LSOA code       0.0
# Crime type      0.0
# Outcome type    0.0
# year            0.0
# month           0.0
# dtype: float64

# %% [markdown]
# ### Modelling

# %%
x = df.drop(['Outcome type'], axis=1)
y = df['Outcome type']

# %%
x_train = df_train.drop(['Outcome type'], axis=1)
y_train = df_train['Outcome type']

# %%
x_test = df_test.drop(['Outcome type'], axis=1)
y_test = df_test['Outcome type']

# %%
x_train
# Out:
#                          Falls within  Longitude   Latitude  LSOA code
# 1273950  Gloucestershire Constabulary  -2.201991  51.839291   0.050000  \
# 164444           Thames Valley Police  -1.201400  51.948703   0.008955
# 305607    Metropolitan Police Service   0.057743  51.514884   0.061856
# 1876867            South Wales Police  -3.754138  51.592297   0.076923
# 1768149         West Yorkshire Police  -1.497631  53.697094   0.041667
# ...                               ...        ...        ...        ...
# 653672            Lincolnshire Police  -0.604097  53.215015   0.040816
# 120705              Humberside Police  -0.644283  53.591509   0.112132
# 1534391          Staffordshire Police  -2.208193  53.000311   0.072165
# 991406         South Yorkshire Police  -1.476687  53.469365   0.043478
# 1000570          Suffolk Constabulary   1.602002  52.450554   0.000000
#
#                            Crime type  year  month
# 1273950                  Public order  2022      9
# 164444                  Vehicle crime  2020      7
# 305607                    Other theft  2020     12
# 1876867     Criminal damage and arson  2022     12
# 1768149  Violence and sexual offences  2022     11
# ...                               ...   ...    ...
# 653672      Criminal damage and arson  2021     12
# 120705                  Vehicle crime  2020      6
# 1534391  Violence and sexual offences  2022     10
# 991406      Criminal damage and arson  2022      7
# 1000570                 Vehicle crime  2022      7
#
# [1704439 rows x 7 columns]

# %%
x_train['Falls within'].nunique()
# Out:
# 42

# %%
x_train['Crime type'].nunique()
# Out:
# 13

# %%
cat_cols = x_train.select_dtypes(include='object').columns.tolist()
int_cols = x_train.select_dtypes(include=['int', 'float']).columns.tolist()
print(cat_cols)
print(f'int cols: {int_cols}')
# Out:
# ['Falls within', 'Crime type']
# int cols: ['Longitude', 'Latitude', 'LSOA code', 'year', 'month']

# %%
numerical_pipeline = Pipeline(
    steps=[
        ('imputation_mode', SimpleImputer(missing_values=np.nan, strategy='median')),
        ('Scaler', MinMaxScaler())
    ]
)

categorical_pipeline = Pipeline(
    steps=[
        ('imputation_cat', SimpleImputer(strategy='most_frequent')),
        ('OneHotEncoder', OneHotEncoder(handle_unknown='ignore', drop='first'))
    ]
)

# %%
cat_transformer = ColumnTransformer(
    transformers=[
        ('numerical_pipeline', numerical_pipeline, int_cols),
        ('categorical_pipeline', categorical_pipeline, cat_cols)
    ]
)

# %%
x_train_p = cat_transformer.fit_transform(x_train)
x_train_p
# Out:
# <1704439x58 sparse matrix of type '<class 'numpy.float64'>'
# 	with 11053634 stored elements in Compressed Sparse Row format>

# %%
x_test_p = cat_transformer.transform(x_test)
x_test_p
# Out:
# <426110x58 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2761847 stored elements in Compressed Sparse Row format>

# %%
print(f'Train set: {x_train_p.shape}')
print(f'Test set: {x_test_p.shape}')
# Out:
# Train set: (1704439, 58)
# Test set: (426110, 58)

# %%
model = RandomForestClassifier()

model.fit(x_train_p, y_train)
