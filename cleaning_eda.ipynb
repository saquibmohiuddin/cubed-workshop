# %%
from glob import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import polars as pl

# %%
pop_xls_file = pd.ExcelFile('data/lsoa_population_data.xlsx')

# %%
pop_xls_file.sheet_names
# Out:
# ['Contents',
#  'Terms and conditions',
#  'Notes and definitions',
#  'Mid-2020 Persons',
#  'Mid-2020 Males',
#  'Mid-2020 Females',
#  'Median Age',
#  'Related publications']

# %%
pop_df = pd.read_excel('data\lsoa_population_data.xlsx', sheet_name='Mid-2020 Persons', header=4)
pop_df
# Out:
# c:\Users\saqui\.conda\envs\lab\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#        LSOA Code            LSOA Name LA Code (2018 boundaries)
# 0      E01011949      Hartlepool 009A                 E06000001  \
# 1      E01011950      Hartlepool 008A                 E06000001
# 2      E01011951      Hartlepool 007A                 E06000001
# 3      E01011952      Hartlepool 002A                 E06000001
# 4      E01011953      Hartlepool 002B                 E06000001
# ...          ...                  ...                       ...
# 34748  W01001320  Merthyr Tydfil 007C                 W06000024
# 34749  W01001321  Merthyr Tydfil 007D                 W06000024
# 34750  W01001322  Merthyr Tydfil 007E                 W06000024
# 34751  W01001324  Merthyr Tydfil 003E                 W06000024
# ...

# %%
pop_df.shape
# Out:
# (34753, 98)

# %%
pop_df.drop(['LA Code (2018 boundaries)', 'LA name (2018 boundaries)', 
             'LA Code (2021 boundaries)', 'LA name (2021 boundaries)'], 
            axis=1, inplace=True, errors='ignore')

# %%
crime_df = pd.read_csv('clean_data\clean_data_v2.csv')
crime_df
# Out:
#                                                   Crime ID    Month
# 0        c9e13644419c09d866b0677c611c270a7ec07469b07b22...  2020-02  \
# 1        b56fb9a76ae74d64bcf2a977260f288ecc0368c287c003...  2020-02
# 2        a645e84c245557bc94c24543bc3fbb001da8bf58c0aa8a...  2020-02
# 3        adb977ce325d741b951aee2b769015322b74f857ce81b7...  2020-02
# 4        b213f886ce58f48c9ca2c39745ab1b8a1825e3239a6ae6...  2020-02
# ...                                                    ...      ...
# 2130544  e5ad1fe3d37c380049cd9b41335af39a3b90efa87cca84...  2023-01
# 2130545  474af4ae9e4f8813c2e5d983d663bb4e1347d1df474a7d...  2023-01
# 2130546  7b01c0f45837c1cb1c75d03f422bc6e34e05148cf6d973...  2023-01
# 2130547  2aa6988775439e9c1b52f17d13d6e434e0f3c91b70fed0...  2023-01
# 2130548  15fab599887a2d8b9312d595c60dc1f74fea52277f99e9...  2023-01
#
#                             Reported by                    Falls within
# 0        Avon and Somerset Constabulary  Avon and Somerset Constabulary  \
# ...

# %%
crime_df.drop(['Crime ID', 'Reported by'], axis=1, inplace=True, errors='ignore')

# %%
crime_df
# Out:
#            Month                    Falls within  Longitude   Latitude
# 0        2020-02  Avon and Somerset Constabulary  -2.350371  51.391561  \
# 1        2020-02  Avon and Somerset Constabulary  -2.360522  51.381127
# 2        2020-02  Avon and Somerset Constabulary  -2.359175  51.383451
# 3        2020-02  Avon and Somerset Constabulary  -2.359175  51.383451
# 4        2020-02  Avon and Somerset Constabulary  -2.359175  51.383451
# ...          ...                             ...        ...        ...
# 2130544  2023-01                Wiltshire Police  -1.759022  50.994660
# 2130545  2023-01                Wiltshire Police  -1.759022  50.994660
# 2130546  2023-01                Wiltshire Police  -1.759022  50.994660
# 2130547  2023-01                Wiltshire Police  -1.750954  50.992992
# 2130548  2023-01                Wiltshire Police  -1.748516  50.993355
#
#                          Location  LSOA code
# 0          On or near Supermarket  E01014468  \
# ...

# %%
crime_df.columns
# Out:
# Index(['Month', 'Falls within', 'Longitude', 'Latitude', 'Location',
#        'LSOA code', 'LSOA name', 'Crime type', 'Outcome type'],
#       dtype='object')

# %%
lsoa_df = df.groupby(['LSOA code', 'LSOA name', 'Falls within'])[['Crime type']].agg('crime').reset_index()
lsoa_df

# %%
pop_df
# Out:
#        LSOA Code            LSOA Name  All Ages   0   1   2   3   4   5   6
# 0      E01011949      Hartlepool 009A      1944  20  32  22  17  27  31  23  \
# 1      E01011950      Hartlepool 008A      1298  14  18  15  13  11  10  17
# 2      E01011951      Hartlepool 007A      1208  18  13  12   9  16  10  11
# 3      E01011952      Hartlepool 002A      1724  23  20  32  19  28  19  29
# 4      E01011953      Hartlepool 002B      2026  27  20  32  39  27  44  34
# ...          ...                  ...       ...  ..  ..  ..  ..  ..  ..  ..
# 34748  W01001320  Merthyr Tydfil 007C      1430  17  15  11   9   6  20  18
# 34749  W01001321  Merthyr Tydfil 007D      1576  21  19  16  26  21  24  19
# 34750  W01001322  Merthyr Tydfil 007E      1626  24  23  22  26  23  24  20
# 34751  W01001324  Merthyr Tydfil 003E      2106  19  20  32  18  29  19  11
# 34752  W01001898  Merthyr Tydfil 008F      1485  13  15  11  13  12  16  16
#
#        ...  81  82  83  84  85  86  87  88  89  90+
# ...

# %%
lsoa_crime_df = crime_df.groupby(['LSOA code', 'LSOA name']).agg({'Month':'count',
                                            'Falls within':', '.join,
                                            'Falls within':'unique',
                                            'Location':', '.join,
                                            'Location':'unique',
                                            'Crime type':', '.join,
                                            'Crime type':'unique'}).reset_index()

# %%
lsoa_crime_df
# Out:
#        LSOA code                  LSOA name  Month
# 0      E01000001        City of London 001A     45  \
# 1      E01000002        City of London 001B    113
# 2      E01000003        City of London 001C     16
# 3      E01000005        City of London 001E    184
# 4      E01000006  Barking and Dagenham 016A     11
# ...          ...                        ...    ...
# 33061  W01001954               Cardiff 006F     13
# 33062  W01001955               Swansea 025F   1255
# 33063  W01001956               Swansea 023E     62
# 33064  W01001957               Swansea 025G    156
# 33065  W01001958               Swansea 025H    142
#
#                                             Falls within
# 0      [City of London Police, Metropolitan Police Se...  \
# 1      [City of London Police, Metropolitan Police Se...
# 2      [City of London Police, Metropolitan Police Se...
# 3      [City of London Police, Metropolitan Police Se...
# 4                          [Metropolitan Police Service]
# ...

# %%
lsoa_crime_df[['Falls within', 'Location', 'Crime type']] = lsoa_crime_df[['Falls within', 'Location', 'Crime type']].applymap(lambda x: ', '.join(x))
lsoa_crime_df
# Out:
#        LSOA code                  LSOA name  Month
# 0      E01000001        City of London 001A     45  \
# 1      E01000002        City of London 001B    113
# 2      E01000003        City of London 001C     16
# 3      E01000005        City of London 001E    184
# 4      E01000006  Barking and Dagenham 016A     11
# ...          ...                        ...    ...
# 33061  W01001954               Cardiff 006F     13
# 33062  W01001955               Swansea 025F   1255
# 33063  W01001956               Swansea 023E     62
# 33064  W01001957               Swansea 025G    156
# 33065  W01001958               Swansea 025H    142
#
#                                             Falls within
# 0      City of London Police, Metropolitan Police Ser...  \
# 1      City of London Police, Metropolitan Police Ser...
# 2      City of London Police, Metropolitan Police Ser...
# 3      City of London Police, Metropolitan Police Ser...
# 4                            Metropolitan Police Service
# ...

# %%
lsoa_crime_df['Crime type'].iloc[0]
# Out:
# 'Drugs, Other theft, Violence and sexual offences, Theft from the person, Other crime, Bicycle theft, Criminal damage and arson, Public order, Vehicle crime'

# %%
pop_crime_location_df = lsoa_crime_df.merge(pop_df, left_on=['LSOA code', 'LSOA name'], right_on=['LSOA Code', 'LSOA Name'], how='left')
pop_crime_location_df
# Out:
#        LSOA code                  LSOA name  Month
# 0      E01000001        City of London 001A     45  \
# 1      E01000002        City of London 001B    113
# 2      E01000003        City of London 001C     16
# 3      E01000005        City of London 001E    184
# 4      E01000006  Barking and Dagenham 016A     11
# ...          ...                        ...    ...
# 33061  W01001954               Cardiff 006F     13
# 33062  W01001955               Swansea 025F   1255
# 33063  W01001956               Swansea 023E     62
# 33064  W01001957               Swansea 025G    156
# 33065  W01001958               Swansea 025H    142
#
#                                             Falls within
# 0      City of London Police, Metropolitan Police Ser...  \
# 1      City of London Police, Metropolitan Police Ser...
# 2      City of London Police, Metropolitan Police Ser...
# 3      City of London Police, Metropolitan Police Ser...
# 4                            Metropolitan Police Service
# ...

# %%
pop_crime_location_df.rename({'Month':'Crime Count'}, axis=1, inplace=True, errors='ignore')

# %%
pop_crime_location_df = pop_crime_location_df[['LSOA code', 'LSOA name', 'Crime Count', 'Crime type', 'Location', 'Falls within', 'All Ages']]
pop_crime_location_df
# Out:
#        LSOA code                  LSOA name  Crime Count
# 0      E01000001        City of London 001A           45  \
# 1      E01000002        City of London 001B          113
# 2      E01000003        City of London 001C           16
# 3      E01000005        City of London 001E          184
# 4      E01000006  Barking and Dagenham 016A           11
# ...          ...                        ...          ...
# 33061  W01001954               Cardiff 006F           13
# 33062  W01001955               Swansea 025F         1255
# 33063  W01001956               Swansea 023E           62
# 33064  W01001957               Swansea 025G          156
# 33065  W01001958               Swansea 025H          142
#
#                                               Crime type
# 0      Drugs, Other theft, Violence and sexual offenc...  \
# 1      Criminal damage and arson, Other theft, Bicycl...
# 2      Theft from the person, Violence and sexual off...
# ...

# %%
pop_crime_location_df.to_csv('clean_data/pop_crime_location_df.csv', index=False)

# %% [markdown]
# ### Only LSOA

# %%
lsoa_df = crime_df.groupby(['LSOA code', 'LSOA name']).agg({'Crime type':'count',
                                            'Falls within':', '.join,
                                            'Falls within':'unique'}).reset_index()

# %%
lsoa_df
# Out:
#        LSOA code                  LSOA name  Crime type
# 0      E01000001        City of London 001A          45  \
# 1      E01000002        City of London 001B         113
# 2      E01000003        City of London 001C          16
# 3      E01000005        City of London 001E         184
# 4      E01000006  Barking and Dagenham 016A          11
# ...          ...                        ...         ...
# 33061  W01001954               Cardiff 006F          13
# 33062  W01001955               Swansea 025F        1255
# 33063  W01001956               Swansea 023E          62
# 33064  W01001957               Swansea 025G         156
# 33065  W01001958               Swansea 025H         142
#
#                                             Falls within
# 0      [City of London Police, Metropolitan Police Se...
# 1      [City of London Police, Metropolitan Police Se...
# 2      [City of London Police, Metropolitan Police Se...
# 3      [City of London Police, Metropolitan Police Se...
# ...

# %%
lsoa_df['Falls within'] = lsoa_df['Falls within'].apply(lambda x: ', '.join(x))
lsoa_df
# Out:
#        LSOA code                  LSOA name  Crime type
# 0      E01000001        City of London 001A          45  \
# 1      E01000002        City of London 001B         113
# 2      E01000003        City of London 001C          16
# 3      E01000005        City of London 001E         184
# 4      E01000006  Barking and Dagenham 016A          11
# ...          ...                        ...         ...
# 33061  W01001954               Cardiff 006F          13
# 33062  W01001955               Swansea 025F        1255
# 33063  W01001956               Swansea 023E          62
# 33064  W01001957               Swansea 025G         156
# 33065  W01001958               Swansea 025H         142
#
#                                             Falls within
# 0      City of London Police, Metropolitan Police Ser...
# 1      City of London Police, Metropolitan Police Ser...
# 2      City of London Police, Metropolitan Police Ser...
# 3      City of London Police, Metropolitan Police Ser...
# ...

# %%
pop_crime_df = lsoa_df.merge(pop_df, left_on=['LSOA code', 'LSOA name'], right_on=['LSOA Code', 'LSOA Name'], how='left')
pop_crime_df
# Out:
#        LSOA code                  LSOA name  Crime type
# 0      E01000001        City of London 001A          45  \
# 1      E01000002        City of London 001B         113
# 2      E01000003        City of London 001C          16
# 3      E01000005        City of London 001E         184
# 4      E01000006  Barking and Dagenham 016A          11
# ...          ...                        ...         ...
# 33061  W01001954               Cardiff 006F          13
# 33062  W01001955               Swansea 025F        1255
# 33063  W01001956               Swansea 023E          62
# 33064  W01001957               Swansea 025G         156
# 33065  W01001958               Swansea 025H         142
#
#                                             Falls within  LSOA Code
# 0      City of London Police, Metropolitan Police Ser...  E01000001  \
# 1      City of London Police, Metropolitan Police Ser...  E01000002
# 2      City of London Police, Metropolitan Police Ser...  E01000003
# ...

# %%
pop_crime_analysis_df = pop_crime_df[['LSOA code', 'LSOA name', 'Crime type', 'Falls within', 'All Ages']]
pop_crime_analysis_df
# Out:
#        LSOA code                  LSOA name  Crime type
# 0      E01000001        City of London 001A          45  \
# 1      E01000002        City of London 001B         113
# 2      E01000003        City of London 001C          16
# 3      E01000005        City of London 001E         184
# 4      E01000006  Barking and Dagenham 016A          11
# ...          ...                        ...         ...
# 33061  W01001954               Cardiff 006F          13
# 33062  W01001955               Swansea 025F        1255
# 33063  W01001956               Swansea 023E          62
# 33064  W01001957               Swansea 025G         156
# 33065  W01001958               Swansea 025H         142
#
#                                             Falls within  All Ages
# 0      City of London Police, Metropolitan Police Ser...      1749
# 1      City of London Police, Metropolitan Police Ser...      1678
# 2      City of London Police, Metropolitan Police Ser...      1900
# ...

# %%
pop_crime_analysis_df.to_csv('clean_data/pop_crime_analysis_df.csv', index=False)

# %%
pop_crime_df.to_csv('clean_data/pop_crime_df.csv', index=False)
